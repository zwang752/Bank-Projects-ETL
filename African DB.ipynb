# %%
from urllib.request import urlopen as uReq
from bs4 import BeautifulSoup as soup
import urllib
import re
import pandas as pd
import itertools
import numpy as np

# %%
def remove(lst):
    remove_lst = ['',' ','  ','Project Details','Source(s) of financing']
    llst = []
    for i in res:
        if i not in remove_lst:
            llst.append(i)
    return llst

# %%
def get_index(lst):
    temp = [] 
    for i in ['Objectives','Description','Benefits']:
        try:
            index = lst.index(i)
            temp.append(index)
        except: pass
    return temp

# %%
global_url = "https://www.afdb.org/" 
df_null = pd.DataFrame()

# %%
url_list = ['https://www.afdb.org/en/projects-and-operations']
for num in range(1,221):
    url_list.append('https://www.afdb.org/en/projects-and-operations?page='+str(num))

for url in url_list:
    try: 
        uClient = uReq(url)
        page_html = uClient.read()
        uClient.close()
        page_soup = soup(page_html, "html.parser")
        links = [a['href'] for a in page_soup.find_all('a', href=True)]
    
        drop_link = []
        for link in links: 
            if '/en/projects-and-operations/p-' in link:
                drop_link.append(link)
        drop_link = list(set(drop_link))
    
        for link in drop_link:
            bluClient = uReq(global_url+link)
            blupage_html = bluClient.read()
            bluClient.close()
            blupage_soup = soup(blupage_html, "html.parser")
       
            lst = blupage_soup.find_all('td')[0].text.split('\n')
            res = [i for i in lst if i] 
            llst = remove(res)
  
            dic = {}
            temp = get_index(llst)
            if len(temp)>0:
                string = llst[0:temp[0]-1]
                for i in string:
                    substr = i.split(': ')
                    dic[substr[0]] = substr[1]
                for i in temp:
                    dic[llst[i]]=llst[i+1]
            else:
                string = llst[0:]
                for i in string:
                    substr = i.split(': ')
                    dic[substr[0]] = substr[1]
            df = pd.DataFrame.from_dict(dic,orient="index").T
            df_null = pd.concat([df_null,df],sort=False)
    except:
            print(llst)
            
    print(url)
# Out:
# [' Project Details', 'ID: P-Z1-DB0-202', 'Name: MULTINATIONAL NACALA ROAD CORRIDOR DEVELOPMENT PROJECT PHASE V - MALAWI', 'Status: Identification', 'Country: Multinational ', 'Sector: Transport', 'Approval date: 19-Jun-2019', 'Task Manager: MAKASA Davies Bwalya, RDGS1 ', 'Total cost: 46702857.14Currency: UAC', 'Source(s) of financingADF: 26600000Cofinanced: 15388571.43Government: 4714285.71', 'Implementing Agency: --', 'Location: MALAWI / ZAMBIA/ MOZAMBIQUE', 'Objectives', 'The project development objectives are two-fold: (i) at regional level, the objective shall contribute to improving road transportation and trade facilitation along the Nacala Transport Corridor; and (ii) at national level, the project shall contribute to reduction of transportation costs along the Lilongwe-Blantyre and Liwonde-Mangochi road corridors respectively which in turn is expected to support stimulation of local economic activities in agriculture, agro-forestry, fisheries and tourism.', 'Description', 'The proposed project, will involve (i) rehabilitation of a 55 km road between Nsipe and Liwonde along the Nacala Road Transport Corridor and (ii) feasibility study of the Salima- Nkhotakhota-Dwangwa Road on the north-south corridor.', 'The project shall be Phase V of the Multinational Nacala Road Corridor Project which the Bank and other development partners are supporting in Malawi, Mozambique and Zambia. The progress on various phases are indicated in Table 1 below. The Nacala Road Corridor stretches from Lusaka in Zambia and transverses through Malawi to the port of Nacala in Mozambique.', 'Benefits', 'The proposed project will contribute to improved movement of goods and services along the Nacala Transport Corridor. The project beneficiaries include an estimated population of over 4 million people along the Nacala Transport Corridor. At national level, the Nsipe-Liwonde-Mangochi road traverses the Balaka and Mangochi districts whose population is about 1.3 million people. The proposed 55km road rehabilitation project between Nsipe and Liwonde and the on-going 75 km road rehabilitation project between Liwonde and Mangochi will contribute are expected to generate an estimated 700,00 temporary jobs and 200 permanent jobs. It is anticipated that 70% of the jobs will be taken up by the youth and 25% by women. In addition to this, roadside markets will be constructed at suitable locations along the road to provide business opportunities for women and youth.']
# https://www.afdb.org/en/projects-and-operations
# [' Project Details', 'ID: P-MA-I00-006', 'Name: PROGRAMME D’APPUI À L’AMÉLIORATION DES RÉSULTATS DES SECTEURS SOCIAUX AU MAROC', 'Status: Approved', 'Country: Morocco ', 'Sector: Social', 'Approval date: 13-Dec-2018', 'Task Manager: KILANI JAAFOR Leila, RDGN2 ', 'Total cost: 66651102Currency: UAC', 'Source(s) of financingAfDB: 66651487.24', "Implementing Agency: MINISTERE DE l'ECONOMIE ET DES FINANCES", 'Location: Maroc']
# https://www.afdb.org/en/projects-and-operations?page=1
# [' Project Details', 'ID: P-MW-AA0-024', 'Name: SHIRE VALLEY TRANSFORMATION PROJECT', 'Status: Approved', 'Country: Malawi ', 'Sector: Agriculture', 'Approval date: 04-Dec-2018', 'Task Manager: SOLIMAN Wael Mohamed Roshdy, RDGS2 ', 'Total cost: 50000000Currency: UAC', 'Source(s) of financingADF: 20000000Government: 1750000NTF: 4500000OPEC: 11060000', 'Implementing Agency: MINISTRY OF AGRICULTURE & FOOD SECURITY', 'Location: Southern Malawi', 'Objectives', 'The major objective of the Lower Shire Valley Irrigation Project is to exploit the high irrigation potential of the Valley through the development of gravity-fed irrigation from the Shire River, expanding coverage and providing complementary infrastructure and services in order to increase agriculture production and farm-based incomes hence ensuring food security and poverty reduction. The implementation of this project will result in the improvement of standards of living of the c ommunity through diversification and cropping intensity of 123 per cent, and transformation of subsistence agriculture into sustainable market oriented production', 'Description', 'The project comprises 5 main components: (a) Irrigation Facilities and Structures - intake and head works, the irrigation distribution system (feeder canal, north junction pipe and south junction canal, main canal, branch canals, tertiary and quaternary irrigation networks, drainage networks, road network and auxiliary facilities); b) Rural Infrastructure development - , Infrastructure Development, Road Network: Domestic Water Supply and Sanitation, Telecommunication, Schools, Health Facilities c) Agricultural Production Development- Farm Size and Cropping Patterns, Crop Selection Criteria, Crop Protection, Livestock Development, Fisheries Development: , d) Agro-Processing Facilities e) Project Management', 'Benefits', 'The direct beneficiaries of this project are the communities that live in the areas targeted in this project i.e. in the Shire Valley of Southern Malawi. These include the smallholder farmers within the project area; ILLOVO; the entrepreneurs, particularly traders, millers, transporters and artisans, who will find gainful business ventures as a result of project implementation; and the presently unemployed population which will benefit from the expansion of job opportunities created by the project. The Shire Valley Irrigation Project management team and the Government of Malawi will also benefit from these interventions that will result into reduced costs of maintenance of the water canals. The various NGOs, CBOs, ADD staff as well as Assembly staff will get support to implement activities in this area.', 'Rational', 'The Agricultural Sector is operating in an environment that is full of challenges. The country experiences recurrent food shortages and a dwindling export base. Since the late 1980s, the food system has been considerably weakened. Crop failures have necessitated substantial commercial grain imports. Food aid has also been justified to provide free access to food for the poorest households. The major challenges for irrigation development include Low levels of irrigation culture among the rural communities; Limited crop diversification; Inappropriate irrigation technologies; Inadequate markets for farm produce; Poor land use practices; High development and farm input costs; and Limited agro-processing and storage facilities. The implementation of the Shire Valley Development Project would boost the commodities market in the country and improve agricultural practices with the involvement of private sector in agro-processing and other agricultural practices.']
# https://www.afdb.org/en/projects-and-operations?page=2
# [' Project Details', 'ID: P-MA-DA0-006', 'Name: PROJET D’EXTENSION ET DE MODERNISATION DE L’AÉROPORT DE RABAT SALÉ', 'Status: Approved', 'Country: Morocco ', 'Sector: Transport', 'Approval date: 05-Nov-2018', 'Task Manager: MOHAMED Ali Ismael, RDGN1 ', 'Total cost: 145144800Currency: UAC', 'Source(s) of financingAfDB: 63660207.28Government: 79787459.79', 'Implementing Agency: OFFICE NATIONAL DES AEROPORTS ONDA', 'Location: Rabat']
# https://www.afdb.org/en/projects-and-operations?page=3
# [' Project Details', 'ID: P-Z1-IZ0-032', "Name: BASSIN DU LAC TCHAD - PROJET D'APPUI A LA REINSERTION SOCIOECONOMIQUE DES GROUPES VULNERABLES-CHAD", 'Status: Approved', 'Country: Multinational ', 'Sector: Social', 'Approval date: 25-Sep-2018', 'Task Manager: DIALLO Amadou Bassirou, RDGC2 ', 'Total cost: 25000000Currency: UAC', 'Source(s) of financingADF: 2500000', 'Implementing Agency: COMMISSION DU BASSIN DU LAC TCHAD', 'Location: JEUNES A RISQUE, FEMMES']
# https://www.afdb.org/en/projects-and-operations?page=4
# [' Project Details', 'ID: P-SD-I00-001', 'Name: EMERGENCY ASSISTANCE TO WHITE NILE STATE 2018', 'Status: Approved', 'Country: Sudan ', 'Sector: Social', 'Approval date: 06-Sep-2018', 'Task Manager: DARBO Suwareh, COSD ', 'Total cost: 712710Currency: UAC', 'Source(s) of financingSRF: 712707.58', 'Implementing Agency: Humanitarian Aid Commission (HAC) Ministry of Security &Social Dev. (MSSD)', 'Location: WHITE NILE STATE', 'Description', 'The AfDB emergency and humanitarian assistance will complement work currently being done by the Government and other donors. The Project components are: (i) construction of 4 schools to avoid overcrowding in classrooms, rehabilitate 4 health centers, and construct 4 new water points); (ii) rehabilitation of existing and affected school classroom structures such as latrines, electrical cabling, and water pumps; and (iii) provision of furniture, refurbishment of equipment, reconditioning, and replacement of academic materials. The total amount of the emergency and humanitarian assistance required is estimated at USD 1.0 million (One Million US Dollars).', 'Benefits', 'Help construct 4 new schools with 8 latrines, provide educational materials, restore and improve water facilities, construct 4 new water points, rehabilitate 4 health centers and provide sanitary facilities to control outbreak of diseases on school campuses and their homes. In this context, the three key areas targeted by the proposed assistance are: (i) halting interruptions in the school calendar and educational program, (ii) provision of better health facilities for school children, and (iii) improvement in the nutritional status of children.', 'Rational', 'The current emergency situation in refugee camps in White Nile State is beyond the capacity of the Government of Sudan (GoS) and its agencies without significant support from the international community. The 2017 humanitarian planned budget for Sudan stands at USD 1.05 billion. By April 2018, only 20% of the total planned budget has been mobilized. Uncertainty remains high about the fate of the severely affected people, mainly women and children.']
# https://www.afdb.org/en/projects-and-operations?page=5
# [' Project Details', 'ID: P-GW-FA0-005', "Name: PROJET DE DEVELOPPEMENT DU SYSTEME DE DISTRIBUTION DE L'ELECTRICITE DANS LA VILLE DE BISSAU", 'Status: Ongoing', 'Country: Guinea-Bissau ', 'Sector: Power', 'Approval date: 03-Jul-2018', 'Task Manager: DJAIGBE Pierre, RDGW1 ', 'Total cost: 20230000Currency: UAC', 'Source(s) of financingADF: 15000000Cofinanced: 5000000Government: 230000', "Implementing Agency: DIRECTION GENERALE DE L'ENERGIE", 'Location: BISSAU']
# https://www.afdb.org/en/projects-and-operations?page=6
# [' Project Details', 'ID: P-RW-E00-008', 'Name: KIGALI BULK WATER SUPPLY PROJECT', 'Status: Ongoing', 'Country: Rwanda ', 'Sector: Water Sup/Sanit', 'Approval date: 19-Jun-2018', 'Task Manager: KIM Yeon-Su, PICU4 ', 'Total cost: 56262381840Currency: UAC', 'Source(s) of financingAfDB: 14215348.31Cofinanced: 6734521.26', 'Implementing Agency: Kigali Water Limited']
# https://www.afdb.org/en/projects-and-operations?page=7
# [' Project Details', 'ID: P-CF-IE0-006', "Name: PROJET COMPLEMENTAIRE D'APPUI A LA RECONSTRUCTION DES COMMUNAUTES DE BASE", 'Status: Ongoing', 'Country: Centrafrique ', 'Sector: Social', 'Approval date: 02-May-2018', 'Task Manager: MORISSI Jean-Chrysostome, RDGC2 ', 'Total cost: 6510000Currency: UAC', 'Source(s) of financingCofinanced: 4000000RWSSI: 2353608.87', "Implementing Agency: GOUVERNEMENT DE CENTRAFRIQUE MINISTERE DE L'ECONOMIE ET DES FINANCES", 'Location: PERIPHERIES DE BANGUI ET DE BAMBARI']
# https://www.afdb.org/en/projects-and-operations?page=8
# [' Project Details', 'ID: P-CF-IE0-006', "Name: PROJET COMPLEMENTAIRE D'APPUI A LA RECONSTRUCTION DES COMMUNAUTES DE BASE", 'Status: Ongoing', 'Country: Centrafrique ', 'Sector: Social', 'Approval date: 02-May-2018', 'Task Manager: MORISSI Jean-Chrysostome, RDGC2 ', 'Total cost: 6510000Currency: UAC', 'Source(s) of financingCofinanced: 4000000RWSSI: 2353608.87', "Implementing Agency: GOUVERNEMENT DE CENTRAFRIQUE MINISTERE DE L'ECONOMIE ET DES FINANCES", 'Location: PERIPHERIES DE BANGUI ET DE BAMBARI']
# https://www.afdb.org/en/projects-and-operations?page=9
# [' Project Details', 'ID: P-CF-IE0-006', "Name: PROJET COMPLEMENTAIRE D'APPUI A LA RECONSTRUCTION DES COMMUNAUTES DE BASE", 'Status: Ongoing', 'Country: Centrafrique ', 'Sector: Social', 'Approval date: 02-May-2018', 'Task Manager: MORISSI Jean-Chrysostome, RDGC2 ', 'Total cost: 6510000Currency: UAC', 'Source(s) of financingCofinanced: 4000000RWSSI: 2353608.87', "Implementing Agency: GOUVERNEMENT DE CENTRAFRIQUE MINISTERE DE L'ECONOMIE ET DES FINANCES", 'Location: PERIPHERIES DE BANGUI ET DE BAMBARI']
# https://www.afdb.org/en/projects-and-operations?page=10
# [' Project Details', 'ID: P-NA-AA0-005', 'Name: NAMIBIA AGRICULTURAL MECHANISATION AND SEED IMPROVEMENT PROJECT (NAMSIP)', 'Status: Ongoing', 'Country: Namibia ', 'Sector: Agriculture', 'Approval date: 04-Dec-2017', 'Task Manager: SILUNGWE Yappy Gregory, RDGS2 ', 'Total cost: 78128400Currency: UAC', 'Source(s) of financingAfDB: 55020935.47Government: 23042897.08', 'Implementing Agency: MIN AGRICULTURE,WATER, FORESTRY', 'Location: Nation-wide (All Regions)', 'Description', 'The Project has 2 components, namely: (a) Component 1 - Value Chain Improvement, with 2 sub-components, (i) Agricultural Mechanisation and (ii) Certified Seed Systems Improvement; and (b) Component 2 - Institutional Support, with 2 sub-components, (i) Capacity Building, and (ii) Project Management. The major activities under each subcomponent are as follows: Sub-component 1.1: Agricultural Mechanisation (ZAR 0.78 billion, 55.3%): (i) Support 111 farmer-cooperatives (total membership 10,681, including 6 ,912 women) with assorted agricultural production, harvesting and processing machinery and equipment; (ii) Procure assorted crop production, harvesting and processing machinery and equipment; (iii) Procure assorted livestock production (animal health, livestock feed and traceability) equipment;and (iv) Supply and install 3 drip/sprinkler irrigation systems (each covering 200ha) for crop production. Sub-component 1.2: Certified Seed Systems Improvement (ZAR 0.21 billion, 14.5%): (i) Supply and install 169 standard drip/sprinkler irrigation systems (each covering 10ha) for production of certified seeds (maize, pearl millet, sorghum and cowpeas); (ii) Procure assorted machinery and equipment for certified seed production and processing; (iii) Facilitate certified seeds production under dryland/rainfed and irrigation; (iv) Support 200 certified seed inspection activities (seed production under dryland/rainfed and irrigation); (v) Facilitate certified seeds distribution to silos; and (vi) Construct 1 full-house certified seed processing plant. Sub-component 2.1: Capacity Building (ZAR 0.07 billion, 4.8%): (i) Support 3 agricultural institutions, under MAWF; (ii) Sensitise and mobilise communities/beneficiaries; (iii) Form/strengthen 111 farmer cooperatives; (iv) Train 2,100 households in food security and nutrition activities; (v) Support infants feeding programme (Government support); (vi) Train 4,000 farmers in various agriculture-related practices; (vii) Facilitate international training for 5 MAWF staff (Training of Trainers/ToT, covering operation and maintenance of agricultural machinery and equipment); (viii) Conduct national/local training for 28 MAWF staff from the participating Regions (Training of Trainers/ToT, covering operation and maintenance of agricultural machinery and equipment); (ix) Facilitate implementation of ESMP activities; and (x) Support gender mainstreaming activities. Sub-component 2.2: Project Management, Monitoring and Evaluation (ZAR 0.36 billion, 25.4%); (i) Establish and support the Project Coordination Unit (PCU) including recruitment of 3 TAs for MAWF; (ii) Facilitate 5 financial audits; (iii) Establish and support activities of Project Steering Committee (PSC); (iv) Carry out Project coordination activities; (v) Prepare and operationalize Project Implementation Manual; (vi) Establish and operationalize gender sensitive participatory Monitoring and Evaluation (M<(>&<)>E) system; (vii) Prepare 5 Project annual work plans and budgets; (viii) Conduct 70 Project progress review meetings; and (ix) Conduct 2 surveys and 2 reviews (MTR <(>&<)>PCR). The Project cost, including physical and price contingencies, is ZAR 1.42 billion (net of taxes and duties) which will be financed by (i) ADB Loan of ZAR 1.00 billion (70.5%) covering all major Project activities, (ii) the Government contribution of ZAR 0.36 billion (25.5%) through in-kind (monetary value) for existing Government staff salaries participating in Project activities, office space ...
# https://www.afdb.org/en/projects-and-operations?page=11
# [' Project Details', 'ID: P-MG-K00-011', "Name: PROGRAMME D'APPUI À LA COMPETITIVITE ECONOMIQUE", 'Status: Completed', 'Country: Madagascar ', 'Sector: Multi-Sector', 'Approval date: 28-Nov-2017', 'Task Manager: UMUBYEYI Angelique, RDGS5 ', 'Total cost: 31872729Currency: UAC', 'Source(s) of financingCofinanced: 31872729', 'Implementing Agency: GOUVERNEMENT DE MADAGASCAR MINISTERE DES FINANCES ET DE ECONOMIE DIR. TRESOR', 'Location: MADAGASCAR - ALL COUNTRY']
# https://www.afdb.org/en/projects-and-operations?page=12
# [' Project Details', 'ID: P-CV-AAZ-003', 'Name: AIDE D’URGENCE LUTTE CHENILLE LÉGIONNAIRE', 'Status: Approved', 'Country: Cape Verde ', 'Sector: Agriculture', 'Approval date: 26-Oct-2017', 'Task Manager: FELLAH Hatem, RDGW2 ', 'Total cost: 709770Currency: UAC', 'Source(s) of financingSRF: 709768.54', 'Implementing Agency: GOUVERNEMENT DE CAP VERT', 'Location: national']
# https://www.afdb.org/en/projects-and-operations?page=13
# [' Project Details', 'ID: P-Z1-EAZ-047', 'Name: PROJET D’APPUI À LA CRÉATION D’UN OBT ET PPI', 'Status: Ongoing', 'Country: Multinational ', 'Sector: Water Sup/Sanit', 'Approval date: 11-Aug-2017', 'Task Manager: BOUGAIRE Francis Daniel, AWTF ', 'Total cost: 1409930.37Currency: UAC', 'Source(s) of financingAWF: 910050.91', 'Implementing Agency: SECRETARIAT GENERAL CEEAC', 'Location: Gabon-Cameroun-Congo-Guinée Equatoriale']
# https://www.afdb.org/en/projects-and-operations?page=14
# [' Project Details', 'ID: P-SS-FA0-006', 'Name: JUBA DISTRIBUTION SYSTEM REHABLITAION AND EXPANSION PROJECT SUPLEMENTARY FINANCING', 'Status: Ongoing', 'Country: South Sudan ', 'Sector: Power', 'Approval date: 12-Apr-2017', 'Task Manager: MUGUWA Andrew, RDGE1 ', 'Total cost: 10610000Currency: UAC', 'Source(s) of financingCofinanced: 10610000', 'Implementing Agency: SOUTHERN SUDAN ELECTRICITY CORPORATION', 'Location: Juba']
# https://www.afdb.org/en/projects-and-operations?page=15
# [' Project Details', 'ID: P-NG-A00-008', 'Name: PLATEAU STATE POTATO VALUE CHAIN SUPPORT PROJECT (PS-PVCP)', 'Status: Ongoing', 'Country: Nigeria ', 'Sector: Agriculture', 'Approval date: 30-Mar-2017', 'Task Manager: AMADOU Ibrahim Ahamed, RDNG ', 'Total cost: 10000000Currency: UAC', 'Source(s) of financingADF: 8000000Government: 2000000', 'Implementing Agency: FEDERAL MINISTRY OF AGRICULTURE & RURAL DEVELOPMENT (FMARD)', 'Location: ABUJA FCT AND 36 STATES OF THE FEDERATIO']
# https://www.afdb.org/en/projects-and-operations?page=16
# [' Project Details', 'ID: P-GA-A00-005', "Name: ETUDE D'UN PROJET D'APPUI AU PROGRAMME GRAINE-PHASE 2", 'Status: Ongoing', 'Country: Gabon ', 'Sector: Agriculture', 'Approval date: 10-Feb-2017', 'Task Manager: LAAJILI Khaled, RDGC2 ', 'Total cost: 993878Currency: UAC', 'Source(s) of financingMICF: 993878', "Implementing Agency: GOUVERNEMENT DE LA REPUBLIQUE DU GABON MINISTERE DE L'ECONOMIE ET DES FINANCES", 'Location: territoire national']
# https://www.afdb.org/en/projects-and-operations?page=17
# [' Project Details', 'ID: P-GW-A00-003', 'Name: PROJET DE DÉVELOPPEMENT DES CHAINES DE VALEUR RIZ', 'Status: Ongoing', 'Country: Guinea-Bissau ', 'Sector: Agriculture', 'Approval date: 23-Jan-2017', 'Task Manager: KITANE Souleye, RDGW2 ', 'Total cost: 4560000Currency: UAC', 'Source(s) of financingADF: 496000Cofinanced: 3719000', "Implementing Agency: MINISTERE DU PLAN, DE LECONOMIE ET DE L'INTEGRATION REGIONALE", 'Location: Guinée Bissau']
# https://www.afdb.org/en/projects-and-operations?page=18

# %%
df_null
# Out:
#              ID                                               Name     Status  \
# 0  P-DZ-KF0-003  APPUI GOUVERNANCE ENTREPRISES PUBLIQUES ET DES...   Approved
# 0  P-RW-E00-012  RWANDA SUSTAINABLE WATER SUPPLY AND SANITATION...   Approved
# 0  P-Z1-DD0-020  FEASIBILITY STUDY OF THE DEEP SEA PORT IN GUIN...   Approved
# 0  P-UG-EB0-007  PREPARATION OF FEASIBILITY STUDIES AND DETAILE...   Approved
# 0  P-Z1-DD0-021  FEASIBILITY STUDY OF A DEEP SEA PORT IN THE NO...   Approved
# 0  P-GA-DD0-002                                  GSEZ PORT PROJECT   Approved
# 0  P-NG-AZ0-001                       SAY NO TO FAMINE FOR NIGERIA   Approved
# 0  P-LR-HAB-002  TRADE FINANCE LINE OF CREDIT INTERNATIONAL BAN...   Approved
# 0  P-GA-E00-001  PROGRAMME INTÉGRÉ D'ALIMENTATION EN EAU POTABL...   Approved
# 0  P-TD-AA0-024  PROJET RENFORCEMENT DE LA RÉSILIENCE POUR LA S...   Approved
# 0  P-NG-KA0-004  NIGERIA - AFRICAN TRADE INSURANCE (ATI) COUNTR...   Approved
# 0  P-LR-HAB-001  TRADE FINANCE LINE OF CREDIT LIBERIAN BANK FOR...   Approved
# 0  P-Z1-DD0-022  STUDIES AND PPP STRUCTURING FOR THE CONSTRUCTI...   Approved
# 0  P-BF-FA0-010  PROGRAMME DESERT TO POWER - PROJET YELEEN D'EL...   Approved
# 0  P-NG-IA0-006  ADDITIONAL LOAN TO IBSDLIEP FOR THE COMPLETION...   Approved
# 0  P-Z1-C00-070  TCHAD-ABN PROGRAMME INTEGRE DE DEVELOPPEMENT E...   Approved
# 0  P-Z1-DZ0-019  OUBANGUI RIVER BRIDGE& BANGUI-KISANGANI-BUJUMB...   Approved
# 0  P-Z1-FA0-162                           SUPPLEMENTARY FINANCING    Approved
# 0  P-SD-AAZ-009  DAL GROUP CO LTD(FOOD AND AGRICULTURAL INVESTM...   Approved
# 0  P-Z1-F00-077            NELSAP BURUNDI – RWANDA INTERCONNECTION   Approved
# 0  P-UG-FAB-007                          ACHWA II HYDROPOWER PLANT    Ongoing
# 0  P-GH-KF0-003   GHANA COCOA SECTOR INSTITUTIONAL SUPPORT PROJECT   Approved
# 0  P-MA-I00-006  PROGRAMME D’APPUI À L’AMÉLIORATION DES RÉSULTA...   Approved
# 0  P-KE-EB0-010   NAIROBI RIVERS BASINS REHABILITATION RESTORATION   Approved
# 0  P-CV-DD0-005  PROJET DE CONSTRUCTION DU PORT DE MAIO ET DE P...   Approved
# 0  P-ET-AAG-005  INTEGRATED AGRO INDUSTRIAL PARK DEVELOPMENT PR...   Approved
# 0  P-ZW-CB0-001  EMERGENCY ASSISTANCE TO SUPPORT EFFORTS TO CON...   Approved
# 0  P-MW-AA0-024                SHIRE VALLEY TRANSFORMATION PROJECT   Approved
# 0  P-EG-I00-015          ENHANCEMENT OF ENTREPRENEURSHIP ECOSYSTEM   Approved
# 0  P-BJ-DB0-017           PROGRAMME D'AMENAGEMENT ROUTE COTONIERES   Approved
# 0  P-MR-AAC-011  PROJET D'APPUI À LA TRANSFORMATION AGRICOLE EN...   Approved
# 0  P-CM-F00-006                      NACHTIGAL HYDRO POWER PROJECT  Completed
# 0  P-GM-AA0-016    RICE VALUE CHAIN TRANSFORMATION PROGRAM (RVCTP)   Approved
# 0  P-MA-K00-016  PROJET D’APPUI AU RENFORCEMENT DES CAPACITES D...   Approved
# 0  P-ML-DB0-015  PROGRAMME D’AMEN. ROUTIER DE LA BRANCHE MALIEN...   Approved
# 0  P-SL-E00-004  FREETOWN WASH & AQUATIC ENVIRONMENT REVAMPING ...   Approved
# 0  P-CI-KF0-003  PROJET D’APPUI À LA GOUVERNANCE DE LA FILIÈRE ...   Approved
# 0  P-Z1-HAA-091  DON À LA BANQUE MAGHRÉBINE D’INVESTISSEMENT ET...   Approved
# 0  P-Z1-KE0-023  EMERGING AFRICA INFRASTRUCTURE FUND PROJECT (E...   Approved
# 0  P-ML-HA0-008                BANQUE DE DEVELOPPEMENT DU MALI BDM   Approved
#
#           Country           Sector Approval date  \
# 0        Algeria      Multi-Sector   18-Dec-2018
# 0         Rwanda   Water Sup/Sanit   14-Dec-2018
# 0  Multinational         Transport   14-Dec-2018
# 0         Uganda   Water Sup/Sanit   18-Dec-2018
# 0  Multinational         Transport   14-Dec-2018
# 0          Gabon         Transport   14-Dec-2018
# 0        Nigeria       Agriculture   14-Dec-2018
# 0        Liberia           Finance   14-Dec-2018
# 0          Gabon   Water Sup/Sanit   10-Jan-2019
# 0           Chad       Agriculture   14-Dec-2018
# 0        Nigeria      Multi-Sector   14-Dec-2018
# 0        Liberia           Finance   14-Dec-2018
# 0  Multinational         Transport   14-Dec-2018
# 0   Burkina Faso             Power   14-Dec-2018
# 0        Nigeria            Social   14-Dec-2018
# 0  Multinational       Environment   14-Dec-2018
# 0  Multinational         Transport   14-Dec-2018
# 0  Multinational             Power   14-Dec-2018
# 0          Sudan       Agriculture   14-Dec-2018
# 0  Multinational             Power   14-Dec-2018
# 0         Uganda             Power   14-Dec-2018
# 0          Ghana      Multi-Sector   11-Dec-2018
# 0        Morocco            Social   13-Dec-2018
# 0          Kenya   Water Sup/Sanit   11-Dec-2018
# 0     Cape Verde         Transport   06-Dec-2018
# 0       Ethiopia       Agriculture   05-Dec-2018
# 0       Zimbabwe       Environment   04-Dec-2018
# 0         Malawi       Agriculture   04-Dec-2018
# 0          Egypt            Social   07-Dec-2018
# 0          Benin         Transport   13-Dec-2018
# 0     Mauritania       Agriculture   12-Dec-2018
# 0       Cameroon             Power   14-Dec-2018
# 0         Gambia       Agriculture   06-Dec-2018
# 0        Morocco      Multi-Sector   12-Dec-2018
# 0           Mali         Transport   11-Dec-2018
# 0   Sierra Leone   Water Sup/Sanit   05-Dec-2018
# 0  Côte D'Ivoire      Multi-Sector   11-Dec-2018
# 0  Multinational           Finance   12-Dec-2018
# 0  Multinational      Multi-Sector   14-Dec-2018
# 0           Mali           Finance   14-Dec-2018
#
#                              Task Manager   Total cost Currency   Government  \
# 0                BOUZGARROU Malek, RDGN1        846400      UAC        50000
# 0                    SHOJI Hikaru, RDGE2   114976728.1      UAC   2952414.03
# 0         CODO Pamphile Stanislas, PICU3       1447940      UAC          NaN
# 0            NTEGE-WASSWA Maureen, RDGE2    1652045.93      UAC    365496.48
# 0         CODO Pamphile Stanislas, PICU3       1443900      UAC          NaN
# 0                    SHUNDO Kenji, PICU4     251515200      UAC          NaN
# 0                MUGOYA Tom Robert, RDNG      11890000      UAC          NaN
# 0                     BA Mohamadou, PIFD       3452250      UAC          NaN
# 0                 ZALI ZALI Bruno, RDGC2      97130890      UAC          NaN
# 0   LAOKOLE Dedjoguere Antoinette, RDGC2     3788973.9      UAC          NaN
# 0                  NEKATI Bleming, PIFD3      10210000      UAC      7710000
# 0                    BA Mohamadou, PIFD3       3562350      UAC          NaN
# 0         CODO Pamphile Stanislas, PICU3       2000000      UAC          NaN
# 0             BAH Adiaratou Binta, PERN1      62000000      UAC       980000
# 0          OLAOYE Bolanle Patricia, RDNG      10000000      UAC          NaN
# 0                    GARBA Louali, AHAI2      15000000      UAC          NaN
# 0         CODO Pamphile Stanislas, PICU3       1447940      UAC          NaN
# 0       WUBESHET ZEGEYE Alemayehu, RDGE1    21925625.7      UAC          NaN
# 0                    FUSI Richard, AHFR1      72177000      UAC          NaN
# 0         RICHARD Humphrey Ndwiga, RDGE4      19790000      UAC      1580000
# 0       AMMAR Tarek Saleh Mostafa, PESD0      78808400      UAC          NaN
# 0                   IBRAHIM Amadou, ECGF       5000000      UAC          NaN
# 0             KILANI JAAFOR Leila, RDGN2      66651102      UAC          NaN
# 0                     SIFUMA John, RDGE2   53818794.87      UAC          NaN
# 0           WADE Mohamed El Abass, RDGW3    31164565.2      UAC  15582354.53
# 0     EZEDINMA Chukwuma Ikechukwu, AHFR2      11000000      UAC          NaN
# 0  ALEOBUA Boniface Osimua Yakubu, RDGS2        716720      UAC          NaN
# 0     SOLIMAN Wael Mohamed Roshdy, RDGS2      50000000      UAC      1750000
# 0          BEN ABDELKARIM Oussama, RDGN2        396000      UAC          NaN
# 0         DIOP Maimounatou Ndiaye, RDGW3     165000000      UAC      6260000
# 0       MAROUKI Rafaa Ben Mohamed, RDGN2      15000000      UAC      2000000
# 0          JALARD Matthieu Benoit, PESR2     786500000      UAC          NaN
# 0          IHEDIOHA Onyema Damian, AHAI1       5000000      UAC          NaN
# 0                     KESSAB Ammar, ECGF        410000      UAC          NaN
# 0                YOUGBARE Barnabe, RDGW3     120000000      UAC          NaN
# 0                  LUBUNGA Rogers, RDGW2     188050000      UAC      3050000
# 0                   IBRAHIM Amadou, ECGF       5000000      UAC          NaN
# 0          SEKIOUA Sofiane Hicham, PIFD1        356000      UAC          NaN
# 0                 BEN AYED Hassen, PICU4     607843500      UAC          NaN
# 0                 DIOP Sidy Gallo, PIFD1      25038300      UAC          NaN
#
#    ...         OPEC     RWSSI   Cofinanced         AWF  \
# 0  ...          NaN       NaN          NaN         NaN
# 0  ...  14542651.16  677742.1          NaN         NaN
# 0  ...          NaN       NaN   1447942.84         NaN
# 0  ...          NaN       NaN          NaN  1256735.93
# 0  ...          NaN       NaN   1443907.79         NaN
# 0  ...          NaN       NaN  218529666.4         NaN
# 0  ...          NaN       NaN          NaN         NaN
# 0  ...          NaN       NaN   2274920.72         NaN
# 0  ...          NaN       NaN  34748651.42         NaN
# 0  ...          NaN       NaN   3788970.33         NaN
# 0  ...          NaN       NaN     17920000         NaN
# 0  ...          NaN       NaN   2351147.43         NaN
# 0  ...          NaN       NaN      2000000         NaN
# 0  ...          NaN       NaN     58020000         NaN
# 0  ...          NaN       NaN          NaN         NaN
# 0  ...          NaN       NaN      1014623         NaN
# 0  ...          NaN       NaN   1447942.84         NaN
# 0  ...          NaN       NaN          NaN         NaN
# 0  ...          NaN       NaN  27066236.49         NaN
# 0  ...          NaN       NaN     15700000         NaN
# 0  ...          NaN       NaN   7522105.19         NaN
# 0  ...          NaN       NaN          NaN         NaN
# 0  ...          NaN       NaN          NaN         NaN
# 0  ...          NaN       NaN          NaN         NaN
# 0  ...          NaN       NaN          NaN         NaN
# 0  ...          NaN       NaN          NaN         NaN
# 0  ...          NaN       NaN          NaN         NaN
# 0  ...     11060000       NaN          NaN         NaN
# 0  ...          NaN       NaN          NaN         NaN
# 0  ...          NaN       NaN     56300000         NaN
# 0  ...          NaN       NaN          NaN         NaN
# 0  ...          NaN       NaN  29493884.93         NaN
# 0  ...          NaN       NaN       770000         NaN
# 0  ...          NaN       NaN          NaN         NaN
# 0  ...          NaN       NaN     79750000         NaN
# 0  ...     20000000       NaN    155000000         NaN
# 0  ...          NaN       NaN          NaN         NaN
# 0  ...          NaN       NaN          NaN         NaN
# 0  ...          NaN       NaN  24154935.12         NaN
# 0  ...          NaN       NaN  13736149.38         NaN
#
#                                           Objectives  \
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0  The overall objective of the project is to con...
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0  Le sous-programme a pour principaux objectifs ...
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0  The major objective of the Lower Shire Valley ...
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0  2.1.1The objectives of the project are to: (i)...
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
#
#                                          Description  \
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0  The project will be implemented under two comp...
# 0                                                NaN
# 0  The project entails design, build, finance and...
# 0                                                NaN
# 0                                                NaN
# 0  Le 1er Sous-programme Intégré pour l'Alimentat...
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0  Design, construction and operation of a 42 MW ...
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0  The location in Ponta do Pau Seco has been cho...
# 0  Using a One Bank approach, the Project will co...
# 0                                                NaN
# 0  The project comprises 5 main components: (a) I...
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0  The pproject will include the following compon...
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
#
#                                             Benefits       ADF        SRF  \
# 0                                                NaN       NaN        NaN
# 0                                                NaN       NaN        NaN
# 0                                                NaN       NaN        NaN
# 0  The AWF will co-finance the project along with...       NaN        NaN
# 0                                                NaN       NaN        NaN
# 0                                                NaN       NaN        NaN
# 0                                                NaN  11890000        NaN
# 0                                                NaN       NaN        NaN
# 0  Le Projet va engendrer chez les 920.000 habita...       NaN        NaN
# 0                                                NaN       NaN        NaN
# 0                                                NaN  10210000        NaN
# 0                                                NaN       NaN        NaN
# 0                                                NaN       NaN        NaN
# 0                                                NaN   3000000        NaN
# 0                                                NaN   3990000        NaN
# 0                                                NaN   7500000        NaN
# 0                                                NaN       NaN        NaN
# 0                                                NaN       NaN        NaN
# 0                                                NaN       NaN        NaN
# 0                                                NaN   2510000        NaN
# 0                                                NaN       NaN        NaN
# 0                                                NaN   5000000        NaN
# 0                                                NaN       NaN        NaN
# 0                                                NaN   2910000        NaN
# 0  The project of the new port of Maio favors the...       NaN        NaN
# 0  The project is expected to generate 13,885 job...  11000000        NaN
# 0                                                NaN       NaN  716717.43
# 0  The direct beneficiaries of this project are t...  20000000        NaN
# 0                                                NaN       NaN        NaN
# 0                                                NaN       NaN        NaN
# 0                                                NaN   7000000        NaN
# 0                                                NaN       NaN        NaN
# 0                                                NaN   4230000        NaN
# 0                                                NaN       NaN        NaN
# 0                                                NaN   5800000        NaN
# 0  The key direct benefits from the project will ...  10000000        NaN
# 0                                                NaN   5000000        NaN
# 0                                                NaN       NaN        NaN
# 0                                                NaN       NaN        NaN
# 0                                                NaN       NaN        NaN
#
#        NTF
# 0      NaN
# 0      NaN
# 0      NaN
# 0      NaN
# 0      NaN
# 0      NaN
# 0      NaN
# 0      NaN
# 0      NaN
# 0      NaN
# 0      NaN
# 0      NaN
# 0      NaN
# 0      NaN
# 0      NaN
# 0      NaN
# 0      NaN
# 0      NaN
# 0      NaN
# 0      NaN
# 0      NaN
# 0      NaN
# 0      NaN
# 0      NaN
# 0      NaN
# 0      NaN
# 0      NaN
# 0  4500000
# 0      NaN
# 0      NaN
# 0  6000000
# 0      NaN
# 0      NaN
# 0      NaN
# 0      NaN
# 0      NaN
# 0      NaN
# 0      NaN
# 0      NaN
# 0      NaN
#
# [40 rows x 24 columns]
